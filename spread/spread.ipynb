# %%
import gridstatus

# %%
import datetime

from gridstatus.ercot_api.ercot_api import describe_one_endpoint, hit_ercot_api, list_all_endpoints
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import datetime
# ----> 3 from gridstatus.ercot_api.ercot_api import describe_one_endpoint, hit_ercot_api, list_all_endpoints
#
# ImportError: cannot import name 'describe_one_endpoint' from 'gridstatus.ercot_api.ercot_api' (c:\Users\qwane\miniforge3\envs\power\Lib\site-packages\gridstatus\ercot_api\ercot_api.py)

# %%
import gridstatus
nyiso = gridstatus.NYISO()
nyiso.get_lmp(date="today", market="REAL_TIME_5_MIN", locations="ALL")
# Out:
# 2025-11-08 20:58:21 - INFO - Requesting http://mis.nyiso.com/public/csv/realtime/20251108realtime_zone.csv
#                           Time            Interval Start  \
# 0    2025-11-08 00:00:00-05:00 2025-11-08 00:00:00-05:00
# 1    2025-11-08 00:00:00-05:00 2025-11-08 00:00:00-05:00
# 2    2025-11-08 00:00:00-05:00 2025-11-08 00:00:00-05:00
# 3    2025-11-08 00:00:00-05:00 2025-11-08 00:00:00-05:00
# 4    2025-11-08 00:00:00-05:00 2025-11-08 00:00:00-05:00
# ...                        ...                       ...
# 1285 2025-11-08 06:55:00-05:00 2025-11-08 06:55:00-05:00
# 1286 2025-11-08 06:55:00-05:00 2025-11-08 06:55:00-05:00
# 1287 2025-11-08 06:55:00-05:00 2025-11-08 06:55:00-05:00
# 1288 2025-11-08 06:55:00-05:00 2025-11-08 06:55:00-05:00
# 1289 2025-11-08 06:55:00-05:00 2025-11-08 06:55:00-05:00
#
#                   Interval End           Market Location Location Type    LMP  \
# 0    2025-11-08 00:05:00-05:00  REAL_TIME_5_MIN   CAPITL          Zone  40.36
# ...

# %%
import gridstatus
caiso = gridstatus.CAISO()
locations = ["TH_NP15_GEN-APND", "TH_SP15_GEN-APND", "TH_ZP26_GEN-APND"]
caiso.get_lmp(date="today", market='DAY_AHEAD_HOURLY', locations=locations)
# Out:
# 2025-11-08 20:58:27 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2025-11-08 20:58:27 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20251108T08:00-0000&enddatetime=20251109T08:00-0000
# 2025-11-08 20:58:29 - DEBUG - Found 1 files: ['20251108_20251109_PRC_LMP_DAM_20251108_03_58_28_v12.csv']
# 2025-11-08 20:58:29 - DEBUG - Parsing file: 20251108_20251109_PRC_LMP_DAM_20251108_03_58_28_v12.csv
#                         Time            Interval Start  \
# 0  2025-11-08 00:00:00-08:00 2025-11-08 00:00:00-08:00
# 1  2025-11-08 00:00:00-08:00 2025-11-08 00:00:00-08:00
# 2  2025-11-08 00:00:00-08:00 2025-11-08 00:00:00-08:00
# 3  2025-11-08 01:00:00-08:00 2025-11-08 01:00:00-08:00
# ...

# %%
ercot = gridstatus.Ercot()
ercot.get_interconnection_queue()
# Out:
# 2025-11-08 21:25:52 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=15933&_1762604752
# 2025-11-08 21:25:52 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=15933&_1762604752 with {}
# 2025-11-08 21:25:53 - INFO - Downloading interconnection queue from: https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1156887386
#         Queue ID                  Project Name         Interconnecting Entity  \
# 0     15INR0064b       Harald (BearKat Wind B)     McCrae Wind Energy II, LLC
# 1      16INR0049                Nazareth Solar         TX Nazareth Solar, LLC
# 2      16INR0081                  Mesteno Wind         Mesteno Windpower, LLC
# 3      16INR0085                  Priddy Wind             ENGIE North America
# 4      16INR0104             Big Sampson Wind   Big Sampson Wind Project, LLC
# ...          ...                           ...                            ...
# ...

# %%
import datetime

from gridstatus.ercot_api.ercot_api import describe_one_endpoint, hit_ercot_api, list_all_endpoints
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 import datetime
# ----> 3 from gridstatus.ercot_api.ercot_api import describe_one_endpoint, hit_ercot_api, list_all_endpoints
#
# ImportError: cannot import name 'describe_one_endpoint' from 'gridstatus.ercot_api.ercot_api' (c:\Users\qwane\miniforge3\envs\power\Lib\site-packages\gridstatus\ercot_api\ercot_api.py)

# %%
iso = gridstatus.Ercot()
# df = iso.get_spp(date="latest", market="REAL_TIME_15_MIN", location_type="Load Zone")
df_lmp = iso.get_lmp(date="latest", location_type="settlement point")
df_lmp
# Out:
# 2025-11-08 21:25:56 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12300&_1762604756
# 2025-11-08 21:25:56 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12300&_1762604756 with {}
# 2025-11-08 21:25:58 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1158397521
# 2025-11-08 21:25:58 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604758
# 2025-11-08 21:25:58 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604758 with {}
# 2025-11-08 21:25:59 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1157320353
#                 Interval Start              Interval End  \
# 0    2025-11-08 06:25:00-06:00 2025-11-08 06:30:00-06:00
# 1    2025-11-08 06:25:00-06:00 2025-11-08 06:30:00-06:00
# ...

# %%
df = iso.get_rtm_spp(year=2023)
df
# Out:
# 2025-11-08 21:26:00 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13061&_1762604760
# 2025-11-08 21:26:00 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13061&_1762604760 with {}
# 2025-11-08 21:26:47 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604807
# 2025-11-08 21:26:47 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604807 with {}
# 2025-11-08 21:26:48 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1157320353
#                             Time            Interval Start  \
# 0      2023-01-01 00:00:00-06:00 2023-01-01 00:00:00-06:00
# 1      2023-01-01 00:00:00-06:00 2023-01-01 00:00:00-06:00
# 2      2023-01-01 00:00:00-06:00 2023-01-01 00:00:00-06:00
# 3      2023-01-01 00:00:00-06:00 2023-01-01 00:00:00-06:00
# ...

# %%
df = iso.get_dam_spp(year=2010)
df
# Out:
# 2025-11-08 21:27:26 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13060&_1762604846
# 2025-11-08 21:27:26 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13060&_1762604846 with {}
# 2025-11-08 21:27:28 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604848
# 2025-11-08 21:27:28 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1762604848 with {}
# 2025-11-08 21:27:29 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1157320353
#                            Time            Interval Start  \
# 0     2010-12-01 00:00:00-06:00 2010-12-01 00:00:00-06:00
# 1     2010-12-01 00:00:00-06:00 2010-12-01 00:00:00-06:00
# 2     2010-12-01 00:00:00-06:00 2010-12-01 00:00:00-06:00
# 3     2010-12-01 00:00:00-06:00 2010-12-01 00:00:00-06:00
# ...

# %%
df = iso.get_spp(year=2022,date="today")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = iso.get_spp(year=2022,date="today")
#       2 df
#
# File c:\Users\qwane\miniforge3\envs\power\Lib\site-packages\gridstatus\lmp_config.py:21, in lmp_config.__call__.<locals>.wrapper(*args, **kwargs)
#      19 @functools.wraps(func)
#      20 def wrapper(*args, **kwargs):
# ---> 21     bound_args = self._get_bound_args(func, args, kwargs)
#      22     if len(args) > 0 and isinstance(args[0], ISOBase):
#      23         bound_args = self._verify_bound_args(bound_args)
#
# File c:\Users\qwane\miniforge3\envs\power\Lib\site-packages\gridstatus\lmp_config.py:146, in lmp_config._get_bound_args(fn, args, kwargs)
#     143 if "start" in kwargs and "date" not in kwargs and len(args) < 2:
#     144     # For @support_date_range which allows start/end kwargs
# ...

# %%
df = iso.get_hourly_load_post_settlements(date="2022-01-01", end="today")
df
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]2025-11-01 16:56:54 - INFO - Fetching historical load data for year 2022
# 2025-11-01 16:56:58 - DEBUG - Changing timezone for DST duplicate at 2022-11-06 01:00:00-06:00
#  25%|██▌       | 1/4 [00:03<00:10,  3.57s/it]2025-11-01 16:56:58 - INFO - Fetching historical load data for year 2023
# 2025-11-01 16:57:01 - DEBUG - Changing timezone for DST duplicate at 2023-11-05 01:00:00-06:00
#  50%|█████     | 2/4 [00:06<00:06,  3.46s/it]2025-11-01 16:57:01 - INFO - Fetching historical load data for year 2024
# 2025-11-01 16:57:04 - DEBUG - Changing timezone for DST duplicate at 2024-11-03 01:00:00-06:00
# ...
# 100%|██████████| 4/4 [00:13<00:00,  3.31s/it]
#                  Interval Start              Interval End         Coast  \
# 0     2022-01-01 00:00:00-06:00 2022-01-01 01:00:00-06:00  12054.939199
# 1     2022-01-01 01:00:00-06:00 2022-01-01 02:00:00-06:00  11793.290315
# 2     2022-01-01 02:00:00-06:00 2022-01-01 03:00:00-06:00  11460.841252
# ...

# %%
df = iso.get_dam_price_corrections(dam_type="DAM_SPP")
df
# Out:
# 2025-11-01 16:53:05 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13044&_1761983585
# 2025-11-01 16:53:05 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13044&_1761983585 with {}
# 2025-11-01 16:53:07 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1145629757
# 2025-11-01 16:53:08 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1761983588
# 2025-11-01 16:53:08 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1761983588 with {}
# 2025-11-01 16:53:09 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1155068495
#           Price Correction Time            Interval Start  \
# 0     2025-09-26 16:00:00-05:00 2025-06-27 00:00:00-05:00
# 1     2025-09-26 16:00:00-05:00 2025-06-27 00:00:00-05:00
# ...

# %%
pjm = gridstatus.PJM()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 pjm = gridstatus.PJM()
#
# File c:\Users\qwane\miniforge3\envs\power\Lib\site-packages\gridstatus\pjm.py:83, in PJM.__init__(self, api_key, retries)
#      80 self.api_key = api_key or os.getenv("PJM_API_KEY")
#      82 if not self.api_key:
# ---> 83     raise ValueError("api_key must be provided or set in PJM_API_KEY env var")
#
# ValueError: api_key must be provided or set in PJM_API_KEY env var
